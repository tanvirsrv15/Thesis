# %%
pip install opendatasets

# %% [markdown]
# # Import Important Library

# %%
import opendatasets as od
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset="https://www.kaggle.com/sobhanmoosavi/us-accidents"
od.download(dataset)
# Out:
# Skipping, found downloaded files in "./us-accidents" (use force=True to force download)

# %%
data_dir="./us-accidents"
os.listdir(data_dir)
# Out:
# ['US_Accidents_Dec21_updated.csv']

# %%
Us_Accident= pd.read_csv('./us-accidents/US_Accidents_Dec21_updated.csv')

# %%
Us_Accident.head()
# Out:
#     ID  Severity           Start_Time             End_Time  Start_Lat  \
# 0  A-1         3  2016-02-08 00:37:08  2016-02-08 06:37:08  40.108910
# 1  A-2         2  2016-02-08 05:56:20  2016-02-08 11:56:20  39.865420
# 2  A-3         2  2016-02-08 06:15:39  2016-02-08 12:15:39  39.102660
# 3  A-4         2  2016-02-08 06:51:45  2016-02-08 12:51:45  41.062130
# 4  A-5         3  2016-02-08 07:53:43  2016-02-08 13:53:43  39.172393
#
#    Start_Lng    End_Lat    End_Lng  Distance(mi)  \
# 0 -83.092860  40.112060 -83.031870         3.230
# 1 -84.062800  39.865010 -84.048730         0.747
# 2 -84.524680  39.102090 -84.523960         0.055
# 3 -81.537840  41.062170 -81.535470         0.123
# 4 -84.492792  39.170476 -84.501798         0.500
#
#                                          Description  ...  Roundabout Station  \
# 0  Between Sawmill Rd/Exit 20 and OH-315/Olentang...  ...       False   False
# 1                 At OH-4/OH-235/Exit 41 - Accident.  ...       False   False
# ...

# %%
Us_Accident.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2845342 entries, 0 to 2845341
# Data columns (total 47 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   ID                     object
#  1   Severity               int64
#  2   Start_Time             object
#  3   End_Time               object
#  4   Start_Lat              float64
#  5   Start_Lng              float64
#  6   End_Lat                float64
#  7   End_Lng                float64
#  8   Distance(mi)           float64
#  9   Description            object
#  10  Number                 float64
#  11  Street                 object
#  12  Side                   object
#  13  City                   object
#  14  County                 object
#  15  State                  object
#  16  Zipcode                object
#  17  Country                object
#  18  Timezone               object
#  19  Airport_Code           object
#  20  Weather_Timestamp      object
# ...

# %% [markdown]
# # Dataset Details

# %% [markdown]
# ID - This is a unique identifier of the accident record.
#
# Severity - Shows the severity of the accident, a number between 1 and 4, where 1 indicates the least impact on traffic (i.e., short delay as a result of the accident) and 4 indicates a significant impact on traffic (i.e., long delay).
#
# Start_Time - Shows start time of the accident in local time zone.
#
# End_Time - Shows end time of the accident in local time zone. End time here refers to when the impact of accident on traffic flow
#
# Start_Lat - Shows latitude in GPS coordinate of the start point.
#
# Start_Lng - Shows longitude in GPS coordinate of the start point.
#
# End_Lat - Shows latitude in GPS coordinate of the end point.
#
# End_Lng - Shows longitude in GPS coordinate of the end point.
#
# Distance(mi) - The length of the road extent affected by the accident.
#
# Description - Shows natural language description of the accident.
#
# Number - Shows the street number in address record.
#
# Street - Shows the street name in address record.
#
# Side - Shows the relative side of the street (Right/Left) in address record.
#
# City - Shows the city in address record.
#
# County - Shows the county in address record.
#
# State - Shows the state in address record.
#
# Zipcode - Shows the zipcode in address record.
#
# Country - Shows the country in address record.
#
# Timezone - Shows timezone based on the location of the accident (eastern, central, etc.).
#
# Airport_Code - Denotes an airport-based weather station which is the closest one to location of the accident.
#
# Weather_Timestamp - Shows the time-stamp of weather observation record (in local time).
#
# Temperature(F) - Shows the temperature (in Fahrenheit).
#
# Wind_Chill(F) - Shows the wind chill (in Fahrenheit).
#
# Humidity(%) - Shows the humidity (in percentage).
#
# Pressure(in) - Shows the air pressure (in inches).
#
# Visibility(mi) - Shows visibility (in miles).
#
# Wind_Direction - Shows wind direction.
#
# Wind_Speed(mph) - Shows wind speed (in miles per hour).
#
# Precipitation(in) - Shows precipitation amount in inches, if there is any.
#
# Weather_Condition - Shows the weather condition (rain, snow, thunderstorm, fog, etc.)
#
# Amenity - A POI annotation which indicates presence of amenity in a nearby location.
#
# Bump - A POI annotation which indicates presence of speed bump or hump in a nearby location.
#
# Crossing - A POI annotation which indicates presence of crossing in a nearby location.
#
# Give_Way - A POI annotation which indicates presence of give_way in a nearby location.
#
# Junction - A POI annotation which indicates presence of junction in a nearby location.
#
# No_Exit - A POI annotation which indicates presence of junction in a nearby location.
#
# Railway - A POI annotation which indicates presence of railway in a nearby location.
#
# Roundabout - A POI annotation which indicates presence of roundabout in a nearby location.
#
# Station - A POI annotation which indicates presence of station in a nearby location.
#
# Stop - A POI annotation which indicates presence of stop in a nearby location.
#
# Traffic_Calming - A POI annotation which indicates presence of traffic_calming in a nearby location.
#
# Traffic_Signal - A POI annotation which indicates presence of traffic_signal in a nearby location.
#
# Turning_Loop - A POI annotation which indicates presence of turning_loop in a nearby location.
#
# Sunrise_Sunset - Shows the period of day (i.e. day or night) based on sunrise/sunset.
#
# Civil_Twilight - Shows the period of day (i.e. day or night) based on civil twilight.
#
# Nautical_Twilight - Shows the period of day (i.e. day or night) based on nautical twilight.
#
# Astronomical_Twilight - Shows the period of day (i.e. day or night) based on astronomical twilight.

# %%
Us_Accident.tail(3)
# Out:
#                 ID  Severity           Start_Time             End_Time  \
# 2845339  A-2845340         2  2019-08-23 19:00:21  2019-08-23 19:28:49
# 2845340  A-2845341         2  2019-08-23 19:00:21  2019-08-23 19:29:42
# 2845341  A-2845342         2  2019-08-23 18:52:06  2019-08-23 19:21:31
#
#          Start_Lat  Start_Lng   End_Lat    End_Lng  Distance(mi)  \
# 2845339   33.77545 -117.84779  33.77740 -117.85727         0.561
# 2845340   33.99246 -118.40302  33.98311 -118.39565         0.772
# 2845341   34.13393 -117.23092  34.13736 -117.23934         0.537
#
#                                                Description  ...  Roundabout  \
# 2845339  At Glassell St/Grand Ave - Accident. in the ri...  ...       False
# 2845340     At CA-90/Marina Fwy/Jefferson Blvd - Accident.  ...       False
# 2845341              At Highland Ave/Arden Ave - Accident.  ...       False
#
#         Station   Stop Traffic_Calming Traffic_Signal Turning_Loop  \
# ...

# %%
Us_Accident.columns
# Out:
# Index(['ID', 'Severity', 'Start_Time', 'End_Time', 'Start_Lat', 'Start_Lng',
#        'End_Lat', 'End_Lng', 'Distance(mi)', 'Description', 'Number', 'Street',
#        'Side', 'City', 'County', 'State', 'Zipcode', 'Country', 'Timezone',
#        'Airport_Code', 'Weather_Timestamp', 'Temperature(F)', 'Wind_Chill(F)',
#        'Humidity(%)', 'Pressure(in)', 'Visibility(mi)', 'Wind_Direction',
#        'Wind_Speed(mph)', 'Precipitation(in)', 'Weather_Condition', 'Amenity',
#        'Bump', 'Crossing', 'Give_Way', 'Junction', 'No_Exit', 'Railway',
#        'Roundabout', 'Station', 'Stop', 'Traffic_Calming', 'Traffic_Signal',
#        'Turning_Loop', 'Sunrise_Sunset', 'Civil_Twilight', 'Nautical_Twilight',
#        'Astronomical_Twilight'],
#       dtype='object')

# %%
Us_Accident.shape
# Out:
# (2845342, 47)

# %% [markdown]
# In this Data set
#
# Total Number of Rows: 2845342
#
# Total Number of Columns: 47

# %%
Us_Accident.describe()
# Out:
#            Severity     Start_Lat     Start_Lng       End_Lat       End_Lng  \
# count  2.845342e+06  2.845342e+06  2.845342e+06  2.845342e+06  2.845342e+06
# mean   2.137572e+00  3.624520e+01 -9.711463e+01  3.624532e+01 -9.711439e+01
# std    4.787216e-01  5.363797e+00  1.831782e+01  5.363873e+00  1.831763e+01
# min    1.000000e+00  2.456603e+01 -1.245481e+02  2.456601e+01 -1.245457e+02
# 25%    2.000000e+00  3.344517e+01 -1.180331e+02  3.344628e+01 -1.180333e+02
# 50%    2.000000e+00  3.609861e+01 -9.241808e+01  3.609799e+01 -9.241772e+01
# 75%    2.000000e+00  4.016024e+01 -8.037243e+01  4.016105e+01 -8.037338e+01
# max    4.000000e+00  4.900058e+01 -6.711317e+01  4.907500e+01 -6.710924e+01
#
#        Distance(mi)        Number  Temperature(F)  Wind_Chill(F)  \
# count  2.845342e+06  1.101431e+06    2.776068e+06   2.375699e+06
# mean   7.026779e-01  8.089408e+03    6.179356e+01   5.965823e+01
# std    1.560361e+00  1.836009e+04    1.862263e+01   2.116097e+01
# ...

# %%
Us_Accident.describe(include='all').T
# Out:
#                            count   unique  \
# ID                       2845342  2845342
# Severity               2845342.0      NaN
# Start_Time               2845342  1959333
# End_Time                 2845342  2351505
# Start_Lat              2845342.0      NaN
# Start_Lng              2845342.0      NaN
# End_Lat                2845342.0      NaN
# End_Lng                2845342.0      NaN
# Distance(mi)           2845342.0      NaN
# Description              2845342  1174563
# Number                 1101431.0      NaN
# Street                   2845340   159651
# Side                     2845342        3
# City                     2845205    11681
# County                   2845342     1707
# State                    2845342       49
# Zipcode                  2844023   363085
# Country                  2845342        1
# Timezone                 2841683        4
# Airport_Code             2835793     2004
# Weather_Timestamp        2794606   474214
# ...

# %%
# Check The numeric columns

numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']

numeric_df = Us_Accident.select_dtypes(include=numerics)
len(numeric_df.columns)
# Out:
# 14

# %% [markdown]
# This Dataset total number of numerical columns are 14,
#
# so, rest of the columns are catagorical

# %% [markdown]
# # Handling Missing Values

# %%
Us_Accident.isna().sum()
# Out:
# ID                             0
# Severity                       0
# Start_Time                     0
# End_Time                       0
# Start_Lat                      0
# Start_Lng                      0
# End_Lat                        0
# End_Lng                        0
# Distance(mi)                   0
# Description                    0
# Number                   1743911
# Street                         2
# Side                           0
# City                         137
# County                         0
# State                          0
# Zipcode                     1319
# Country                        0
# Timezone                    3659
# Airport_Code                9549
# Weather_Timestamp          50736
# Temperature(F)             69274
# Wind_Chill(F)             469643
# Humidity(%)                73092
# Pressure(in)               59200
# Visibility(mi)             70546
# Wind_Direction             73775
# Wind_Speed(mph)           157944
# ...

# %%
Us_Accident.isna().sum().sort_values(ascending=False)
# Out:
# Number                   1743911
# Precipitation(in)         549458
# Wind_Chill(F)             469643
# Wind_Speed(mph)           157944
# Wind_Direction             73775
# Humidity(%)                73092
# Weather_Condition          70636
# Visibility(mi)             70546
# Temperature(F)             69274
# Pressure(in)               59200
# Weather_Timestamp          50736
# Airport_Code                9549
# Timezone                    3659
# Nautical_Twilight           2867
# Civil_Twilight              2867
# Sunrise_Sunset              2867
# Astronomical_Twilight       2867
# Zipcode                     1319
# City                         137
# Street                         2
# Country                        0
# Junction                       0
# Start_Time                     0
# End_Time                       0
# Start_Lat                      0
# Turning_Loop                   0
# Traffic_Signal                 0
# Traffic_Calming                0
# ...

# %%
missing_percentage=Us_Accident.isna().sum().sort_values(ascending=False)/ len(Us_Accident)*100
print('Missing Percentage of dataset by columns: ')
print('                                         ')
missing_percentage
# Out:
# Missing Percentage of dataset by columns:
# Number                   61.290031
# Precipitation(in)        19.310789
# Wind_Chill(F)            16.505678
# Wind_Speed(mph)           5.550967
# Wind_Direction            2.592834
# Humidity(%)               2.568830
# Weather_Condition         2.482514
# Visibility(mi)            2.479350
# Temperature(F)            2.434646
# Pressure(in)              2.080593
# Weather_Timestamp         1.783125
# Airport_Code              0.335601
# Timezone                  0.128596
# Nautical_Twilight         0.100761
# Civil_Twilight            0.100761
# Sunrise_Sunset            0.100761
# Astronomical_Twilight     0.100761
# Zipcode                   0.046356
# City                      0.004815
# Street                    0.000070
# Country                   0.000000
# Junction                  0.000000
# Start_Time                0.000000
# End_Time                  0.000000
# Start_Lat                 0.000000
# ...

# %%
missing_percentage[missing_percentage !=0]
# Out:
# Number                   61.290031
# Precipitation(in)        19.310789
# Wind_Chill(F)            16.505678
# Wind_Speed(mph)           5.550967
# Wind_Direction            2.592834
# Humidity(%)               2.568830
# Weather_Condition         2.482514
# Visibility(mi)            2.479350
# Temperature(F)            2.434646
# Pressure(in)              2.080593
# Weather_Timestamp         1.783125
# Airport_Code              0.335601
# Timezone                  0.128596
# Nautical_Twilight         0.100761
# Civil_Twilight            0.100761
# Sunrise_Sunset            0.100761
# Astronomical_Twilight     0.100761
# Zipcode                   0.046356
# City                      0.004815
# Street                    0.000070
# dtype: float64

# %% [markdown]
# We can see that, Total 20 number of columns have missing values, Now we can see it graphically

# %%
# Plot the percentage of missing values by column
x=missing_percentage[missing_percentage !=0]
x.plot(kind='barh',figsize=(20,10),color='green')

# %% [markdown]
# **We can see that,**
#
# Number, Precipitation(in), Wind_Chill(F), Wind_Speed(mph),Wind_Direction have notable number of missing values.

# %% [markdown]
# # Columns which we will analyze & visualize
# ### 1. State
# ### 2. City
# ### 3. Start Time
# ### 4. Temparature
# ### 5. Weather Conditions

# %% [markdown]
# We know that Traffic accidents are one of the most important concerns of the world, since they result in numerous casualties, injuries, and fatalities each year, as well as significant economic losses. There are many factors that are responsible for causing road accidents. If these factors can be better understood and predicted, it might be possible to take measures to mitigate the damages and its severity.
#
#
#
#
# So, Our Aim is to analyze the important factors which is responsible for accident, which can help to improve the overall traffic conditions for Intelligent Transportation System.

# %% [markdown]
# ***At First We will analyze the State Column***

# %%
Us_Accident.State
# Out:
# 0          OH
# 1          OH
# 2          OH
# 3          OH
# 4          OH
#            ..
# 2845337    CA
# 2845338    CA
# 2845339    CA
# 2845340    CA
# 2845341    CA
# Name: State, Length: 2845342, dtype: object

# %%
State=Us_Accident.State.unique()

len(State)
# Out:
# 49

# %%
State[:10]
# Out:
# array(['OH', 'IN', 'KY', 'WV', 'MI', 'PA', 'CA', 'NV', 'MN', 'TX'],
#       dtype=object)

# %%
State_by_accidents=Us_Accident.State.value_counts()
State_by_accidents
# Out:
# CA    795868
# FL    401388
# TX    149037
# OR    126341
# VA    113535
# NY    108049
# PA     99975
# MN     97185
# NC     91362
# SC     89216
# MD     65085
# AZ     56504
# NJ     52902
# TN     52613
# UT     49193
# LA     47232
# IL     47105
# MI     43843
# GA     40086
# WA     32554
# CT     29762
# MO     29633
# CO     25340
# OH     24409
# IN     20850
# AL     19322
# MT     15964
# AR     10935
# IA      9607
# DC      9133
# KS      9033
# OK      8806
# ID      8544
# WI      7896
# WV      7632
# KY      6638
# MA      6392
# NV      6197
# MS      5320
# DE      4842
# RI      4451
# NH      3866
# NE      3320
# NM      2370
# ND      2258
# ME      2193
# WY       990
# VT       365
# SD       201
# Name: State, dtype: int64

# %%
State_Accident_Percentage=Us_Accident.State.value_counts()/len(Us_Accident['State'])*100
print(State_Accident_Percentage)
# Out:
# CA    27.970908
# FL    14.106846
# TX     5.237929
# OR     4.440275
# VA     3.990206
# NY     3.797399
# PA     3.513637
# MN     3.415582
# NC     3.210932
# SC     3.135511
# MD     2.287423
# AZ     1.985842
# NJ     1.859249
# TN     1.849092
# UT     1.728896
# LA     1.659976
# IL     1.655513
# MI     1.540869
# GA     1.408829
# WA     1.144116
# CT     1.045990
# MO     1.041457
# CO     0.890578
# OH     0.857858
# IN     0.732777
# AL     0.679075
# MT     0.561057
# AR     0.384312
# IA     0.337640
# DC     0.320981
# KS     0.317466
# OK     0.309488
# ID     0.300280
# WI     0.277506
# WV     0.268228
# KY     0.233294
# MA     0.224648
# NV     0.217795
# MS     0.186972
# DE     0.170173
# RI     0.156431
# NH     0.135871
# NE     0.116682
# NM     0.083294
# ND     0.079358
# ME     0.077073
# WY     0.034794
# VT     0.012828
# SD     0.007064
# Name: State, dtype: float64

# %%
# Top Ten State by accident
State_by_accidents[:10]
# Out:
# CA    795868
# FL    401388
# TX    149037
# OR    126341
# VA    113535
# NY    108049
# PA     99975
# MN     97185
# NC     91362
# SC     89216
# Name: State, dtype: int64

# %%
# Top Ten State Accident percentage
State_Accident_Percentage[:10]
# Out:
# CA    27.970908
# FL    14.106846
# TX     5.237929
# OR     4.440275
# VA     3.990206
# NY     3.797399
# PA     3.513637
# MN     3.415582
# NC     3.210932
# SC     3.135511
# Name: State, dtype: float64

# %%
# Top Ten States by accident
import matplotlib.pyplot as plt
plt.title("Top Ten State Accident Count",color='blue')
State_by_accidents[:10].plot(kind='bar',color='green',figsize=(10,5))

# %%
plt.title("Top Ten State Accident Percentage",color='red')
State_Accident_Percentage[:10].plot(kind='bar',color='green',figsize=(10,5))

# %%
import seaborn as sns
sns.set_style("darkgrid")
sns.distplot(State_by_accidents)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
high_accident_state = State_by_accidents[State_by_accidents>=10000]
low_accident_state  = State_by_accidents[State_by_accidents<10000]

print("Length of high accident state: ",len(high_accident_state))
print("Length of Low accident state: ",len(low_accident_state))
# Out:
# Length of high accident state:  28
# Length of Low accident state:  21

# %%
sns.distplot(high_accident_state,color='green')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(low_accident_state,color='green')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ## Insights of State Column
#
# 1. Total 49 states in Dataset
# 2. 'CA' which means California is the state which have most number of
# accident which is 795868 (27.970908 %)
# 3. Florida is the second highest rate of accident which is 401388 (14.106846 % )
# 4. Rest of the state accident percentage is below 10 %
# 5. Almost 42.077 % accident happen in California & Florida State

# %% [markdown]
# ## Analyze of City column

# %%
cities=Us_Accident.City.unique()

len(cities)
# Out:
# 11682

# %%
cities_by_accidents=Us_Accident.City.value_counts()
cities_by_accidents
# Out:
# Miami                           106966
# Los Angeles                      68956
# Orlando                          54691
# Dallas                           41979
# Houston                          39448
#                                  ...
# Ridgedale                            1
# Sekiu                                1
# Wooldridge                           1
# Bullock                              1
# American Fork-Pleasant Grove         1
# Name: City, Length: 11681, dtype: int64

# %%
# Top Ten Cities by accident
cities_by_accidents[:10]
# Out:
# Miami          106966
# Los Angeles     68956
# Orlando         54691
# Dallas          41979
# Houston         39448
# Charlotte       33152
# Sacramento      32559
# San Diego       26627
# Raleigh         22840
# Minneapolis     22768
# Name: City, dtype: int64

# %%
# Top Twenty Cities by accident
cities_by_accidents[:20]
# Out:
# Miami           106966
# Los Angeles      68956
# Orlando          54691
# Dallas           41979
# Houston          39448
# Charlotte        33152
# Sacramento       32559
# San Diego        26627
# Raleigh          22840
# Minneapolis      22768
# Portland         20944
# Nashville        20267
# Austin           18301
# Baton Rouge      18182
# Phoenix          17143
# Saint Paul       16869
# New Orleans      16251
# Atlanta          15622
# Jacksonville     14967
# Richmond         14349
# Name: City, dtype: int64

# %%
# Top Twenty Cities by accident
plt.title("Top Ten Cities by Accident in Us",color='red')
cities_by_accidents[:10].plot(kind='barh',figsize=(8,6))

# %% [markdown]
# ## Start Time

# %%
Us_Accident.Start_Time
# Out:
# 0          2016-02-08 00:37:08
# 1          2016-02-08 05:56:20
# 2          2016-02-08 06:15:39
# 3          2016-02-08 06:51:45
# 4          2016-02-08 07:53:43
#                   ...
# 2845337    2019-08-23 18:03:25
# 2845338    2019-08-23 19:11:30
# 2845339    2019-08-23 19:00:21
# 2845340    2019-08-23 19:00:21
# 2845341    2019-08-23 18:52:06
# Name: Start_Time, Length: 2845342, dtype: object

# %%
# Check null values
Us_Accident.Start_Time.isna().sum()
# Out:
# 0

# %%
# convert to date time
Us_Accident.Start_Time=pd.to_datetime(Us_Accident.Start_Time)
Us_Accident.Start_Time
# Out:
# 0         2016-02-08 00:37:08
# 1         2016-02-08 05:56:20
# 2         2016-02-08 06:15:39
# 3         2016-02-08 06:51:45
# 4         2016-02-08 07:53:43
#                   ...
# 2845337   2019-08-23 18:03:25
# 2845338   2019-08-23 19:11:30
# 2845339   2019-08-23 19:00:21
# 2845340   2019-08-23 19:00:21
# 2845341   2019-08-23 18:52:06
# Name: Start_Time, Length: 2845342, dtype: datetime64[ns]

# %%
Us_Accident.Start_Time[0]
# Out:
# Timestamp('2016-02-08 00:37:08')

# %%
import matplotlib.ticker as ticker

# %%
hour = pd.DataFrame(Us_Accident.Start_Time.dt.hour.value_counts()).reset_index().rename(columns={"index":"Hour","Start_Time":"Accident_Cases"})

# %%
plt.figure(figsize=(10,4))
plt.title('\n Accident cases for different hours of a day\n', size=20, color='black')
plt.xlabel('\n Hours \n', fontsize=15, color='grey')
plt.ylabel('\nAccident Cases\n', fontsize=15, color='grey')
plt.xticks(fontsize=13)
plt.yticks(fontsize=12)
a = sns.barplot(x=hour.Hour,y=hour.Accident_Cases,palette="pastel")
a.yaxis.set_major_formatter(ticker.EngFormatter())
plt.show()

# %%
for (i,j) in zip(hour.Hour,range(0,24)):
  print("Percentage of accidents occuring at {} hour is {:.2f}%".format(i,(hour.Accident_Cases[j]/hour.Accident_Cases.sum())*100))
# Out:
# Percentage of accidents occuring at 17 hour is 7.74%
# Percentage of accidents occuring at 16 hour is 7.68%
# Percentage of accidents occuring at 15 hour is 7.53%
# Percentage of accidents occuring at 14 hour is 6.73%
# Percentage of accidents occuring at 18 hour is 5.94%
# Percentage of accidents occuring at 13 hour is 5.85%
# Percentage of accidents occuring at 12 hour is 5.05%
# Percentage of accidents occuring at 7 hour is 4.75%
# Percentage of accidents occuring at 8 hour is 4.60%
# Percentage of accidents occuring at 19 hour is 4.11%
# Percentage of accidents occuring at 11 hour is 3.98%
# Percentage of accidents occuring at 6 hour is 3.91%
# Percentage of accidents occuring at 9 hour is 3.82%
# Percentage of accidents occuring at 10 hour is 3.65%
# Percentage of accidents occuring at 20 hour is 3.33%
# Percentage of accidents occuring at 21 hour is 3.06%
# Percentage of accidents occuring at 22 hour is 2.85%
# Percentage of accidents occuring at 5 hour is 2.82%
# ...

# %% [markdown]
# We Know that,
# 1. Morning Rush from 5am to 10am
# 2. Office Hours from 10am to 4pm (or: 10:00 - 16:00)
# 3. Afternoon Rush from 4pm to 7pm (or: 16:00 - 19:00)
# 4. Evening from 7pm to 11pm (or: 19:00 - 23:00)
# 5. Night from 11pm to 5am (or: 23:00 - 05:00)
#
# So,
# 1.  In the morning Total percentage of accident is 22.83 %
# 2.  In Office Hours Total percentage of accident is 36.82%
# 3.  In Afternoon Rush Total percentage of accident is 17.79%
# 4.  In Evening Total percentage of accident is 11.85%
# 4.  In Night Total percentage of accident is 9.99%

# %%
day = pd.DataFrame(Us_Accident.Start_Time.dt.day_name().value_counts()).reset_index().rename(columns={'index':'Day', 'Start_Time':'Cases'})

# %%
plt.figure(figsize=(10,4))
plt.title('\n Accident cases for different days of a week\n', size=20, color='black')
plt.xlabel('\n Day \n', fontsize=15, color='grey')
plt.ylabel('\nAccident Cases\n', fontsize=15, color='grey')
plt.xticks(fontsize=13)
plt.yticks(fontsize=12)
a = sns.barplot(x=day.Day,y=day.Cases,palette="muted")
a.yaxis.set_major_formatter(ticker.EngFormatter())
plt.show()

# %%
for (i,j) in zip(day.Day,range(0,7)):
  print("Percentage of accidents occuring at {} hour is {:.2f}%".format(i,(day.Cases[j]/day.Cases.sum())*100))
# Out:
# Percentage of accidents occuring at Friday hour is 17.29%
# Percentage of accidents occuring at Thursday hour is 16.29%
# Percentage of accidents occuring at Wednesday hour is 15.99%
# Percentage of accidents occuring at Tuesday hour is 15.60%
# Percentage of accidents occuring at Monday hour is 14.75%
# Percentage of accidents occuring at Saturday hour is 10.95%
# Percentage of accidents occuring at Sunday hour is 9.11%

# %%
# Lets look at Thursday first.
plt.figure(figsize=(15,5))
plt.title('\n Accident cases reported for different hours on Thursday\n', size=20, color='grey')
plt.xlabel('\n hours \n', fontsize=15, color='grey')
plt.ylabel('\nAccident Cases\n', fontsize=15, color='grey')
plt.xticks(fontsize=13)
plt.yticks(fontsize=12)
thursday = Us_Accident.Start_Time[Us_Accident.Start_Time.dt.dayofweek==0]
a = sns.histplot(thursday.dt.hour,bins=24,color="black")
a.xaxis.set_ticks(range(0,24))
# More accidents take place in the morning and in the evening after people are going to/coming from their job.
plt.show()

# %%
# Lets look at Wednesday 
plt.figure(figsize=(15,5))
plt.title('\n Accident cases reported for different hours on Wednesday\n', size=20, color='black')
plt.xlabel('\n hours \n', fontsize=15, color='black')
plt.ylabel('\nAccident Cases\n', fontsize=15, color='black')
plt.xticks(fontsize=13)
plt.yticks(fontsize=12)
wednesday= Us_Accident.Start_Time[Us_Accident.Start_Time.dt.dayofweek==1]
a = sns.histplot(wednesday.dt.hour,bins=24,color="green")
a.xaxis.set_ticks(range(0,24))
# More accidents take place in the morning and in the evening after people are going to/coming from their job.
plt.show()

# %%
# Lets look at Friday 
plt.figure(figsize=(15,5))
plt.title('\n Accident cases reported for different hours on Friday\n', size=20, color='black')
plt.xlabel('\n hours \n', fontsize=15, color='black')
plt.ylabel('\nAccident Cases\n', fontsize=15, color='black')
plt.xticks(fontsize=13)
plt.yticks(fontsize=12)
Friday= Us_Accident.Start_Time[Us_Accident.Start_Time.dt.dayofweek==2]
a = sns.histplot(Friday.dt.hour,bins=24,color="blue")
a.xaxis.set_ticks(range(0,24))
# More accidents take place in the morning and in the evening after people are going to/coming from their job.
plt.show()

# %%
# Lets look at Tuesday
plt.figure(figsize=(15,5))
plt.title('\n Accident cases reported for different hours on Tuesday\n', size=20, color='black')
plt.xlabel('\n hours \n', fontsize=15, color='black')
plt.ylabel('\nAccident Cases\n', fontsize=15, color='black')
plt.xticks(fontsize=13)
plt.yticks(fontsize=12)
Tuesday= Us_Accident.Start_Time[Us_Accident.Start_Time.dt.dayofweek==3]
a = sns.histplot(Tuesday.dt.hour,bins=24,color="red")
a.xaxis.set_ticks(range(0,24))
# More accidents take place in the morning and in the evening after people are going to/coming from their job.
plt.show()

# %%
# Lets look at Monday
plt.figure(figsize=(15,5))
plt.title('\n Accident cases reported for different hours on Monday\n', size=20, color='black')
plt.xlabel('\n hours \n', fontsize=15, color='black')
plt.ylabel('\nAccident Cases\n', fontsize=15, color='black')
plt.xticks(fontsize=13)
plt.yticks(fontsize=12)
Monday= Us_Accident.Start_Time[Us_Accident.Start_Time.dt.dayofweek==4]
a = sns.histplot(Monday.dt.hour,bins=24,color="purple")
a.xaxis.set_ticks(range(0,24))
# More accidents take place in the morning and in the evening after people are going to/coming from their job.
plt.show()

# %%
# Lets look at Saturday
plt.figure(figsize=(15,5))
plt.title('\n Accident cases reported for different hours on Saturday\n', size=20, color='black')
plt.xlabel('\n hours \n', fontsize=15, color='black')
plt.ylabel('\nAccident Cases\n', fontsize=15, color='black')
plt.xticks(fontsize=13)
plt.yticks(fontsize=12)
Saturday= Us_Accident.Start_Time[Us_Accident.Start_Time.dt.dayofweek==5]
a = sns.histplot(Saturday.dt.hour,bins=24,color="cyan")
a.xaxis.set_ticks(range(0,24))
# More accidents take place in the morning and in the evening after people are going to/coming from their job.
plt.show()

# %%
# Lets look at Sunday
plt.figure(figsize=(15,5))
plt.title('\n Accident cases reported for different hours on Sunday\n', size=20, color='black')
plt.xlabel('\n hours \n', fontsize=15, color='black')
plt.ylabel('\nAccident Cases\n', fontsize=15, color='black')
plt.xticks(fontsize=13)
plt.yticks(fontsize=12)
Sunday= Us_Accident.Start_Time[Us_Accident.Start_Time.dt.dayofweek==5]
a = sns.histplot(Sunday.dt.hour,bins=24,color="olive")
a.xaxis.set_ticks(range(0,24))
# More accidents take place in the morning and in the evening after people are going to/coming from their job.
plt.show()

# %%
import calendar
month = pd.DataFrame(Us_Accident.Start_Time.dt.month.value_counts()).reset_index().rename(columns={"index":"Month","Start_Time":"Accident_Cases"}).sort_values('Month')
month_names = list(calendar.month_name)[1:]
month.Month = month_names

# %%
plt.figure(figsize=(8,4))
plt.title('\n Accident cases reported for different months in US (2016-2021)\n', size=18, color='black')
plt.ylabel('\n Months \n', fontsize=15, color='black')
plt.xlabel('\nAccident Cases\n', fontsize=15, color='black')
plt.xticks(fontsize=13)
plt.yticks(fontsize=12)

a = sns.barplot(x=month.Accident_Cases,y=month.Month,palette="plasma")
a.xaxis.set_major_formatter(ticker.EngFormatter())
plt.show()

# %%
for (i,j) in zip(month.Month,range(0,12)):
  print("Percentage of accidents occuring in month {} is {:.2f}%".format(month.Month[j],(month.Accident_Cases[j]/month.Accident_Cases.sum())*100))
# Out:
# Percentage of accidents occuring in month December is 16.66%
# Percentage of accidents occuring in month November is 12.68%
# Percentage of accidents occuring in month October is 10.51%
# Percentage of accidents occuring in month September is 8.50%
# Percentage of accidents occuring in month June is 7.96%
# Percentage of accidents occuring in month January is 6.97%
# Percentage of accidents occuring in month February is 6.85%
# Percentage of accidents occuring in month May is 6.39%
# Percentage of accidents occuring in month August is 6.28%
# Percentage of accidents occuring in month April is 6.04%
# Percentage of accidents occuring in month July is 5.59%
# Percentage of accidents occuring in month March is 5.56%

# %%
plt.figure(figsize=(15,7))
plt.title('\n Accident cases reported for different months in US (2016)\n', size=20, color='grey')
plt.xlabel('\n Months \n', fontsize=15, color='grey')
plt.ylabel('\nAccident Cases\n', fontsize=15, color='grey')
plt.xticks(fontsize=13)
plt.yticks(fontsize=12)
year = Us_Accident.Start_Time[Us_Accident.Start_Time.dt.year==2016]
a = sns.histplot(year.dt.month,bins=12,color="forestgreen")
a.yaxis.set_major_formatter(ticker.EngFormatter())
plt.show()

# %%
plt.figure(figsize=(15,7))
plt.title('\n Accident cases reported for different months in US (2017)\n', size=20, color='grey')
plt.xlabel('\n Months \n', fontsize=15, color='grey')
plt.ylabel('\nAccident Cases\n', fontsize=15, color='grey')
plt.xticks(fontsize=13)
plt.yticks(fontsize=12)
year = Us_Accident.Start_Time[Us_Accident.Start_Time.dt.year==2017]
a = sns.histplot(year.dt.month,bins=12,color="forestgreen")
a.yaxis.set_major_formatter(ticker.EngFormatter())
plt.show()

# %%
plt.figure(figsize=(15,7))
plt.title('\n Accident cases reported for different months in US (2018)\n', size=20, color='grey')
plt.xlabel('\n Months \n', fontsize=15, color='grey')
plt.ylabel('\nAccident Cases\n', fontsize=15, color='grey')
plt.xticks(fontsize=13)
plt.yticks(fontsize=12)
year = Us_Accident.Start_Time[Us_Accident.Start_Time.dt.year==2018]
a = sns.histplot(year.dt.month,bins=12,color="forestgreen")
a.yaxis.set_major_formatter(ticker.EngFormatter())
plt.show()

# %%
plt.figure(figsize=(15,7))
plt.title('\n Accident cases reported for different months in US (2019)\n', size=20, color='grey')
plt.xlabel('\n Months \n', fontsize=15, color='grey')
plt.ylabel('\nAccident Cases\n', fontsize=15, color='grey')
plt.xticks(fontsize=13)
plt.yticks(fontsize=12)
year = Us_Accident.Start_Time[Us_Accident.Start_Time.dt.year==2019]
a = sns.histplot(year.dt.month,bins=12,color="forestgreen")
a.yaxis.set_major_formatter(ticker.EngFormatter())
plt.show()

# %%
plt.figure(figsize=(15,7))
plt.title('\n Accident cases reported for different months in US (2020)\n', size=20, color='grey')
plt.xlabel('\n Months \n', fontsize=15, color='grey')
plt.ylabel('\nAccident Cases\n', fontsize=15, color='grey')
plt.xticks(fontsize=13)
plt.yticks(fontsize=12)
year = Us_Accident.Start_Time[Us_Accident.Start_Time.dt.year==2020]
a = sns.histplot(year.dt.month,bins=12,color="forestgreen")
a.yaxis.set_major_formatter(ticker.EngFormatter())
plt.show()

# %%
plt.figure(figsize=(15,7))
plt.title('\n Accident cases reported for different months in US (2021)\n', size=20, color='grey')
plt.xlabel('\n Months \n', fontsize=15, color='grey')
plt.ylabel('\nAccident Cases\n', fontsize=15, color='grey')
plt.xticks(fontsize=13)
plt.yticks(fontsize=12)
year = Us_Accident.Start_Time[Us_Accident.Start_Time.dt.year==2021]
a = sns.histplot(year.dt.month,bins=12,color="forestgreen")
a.yaxis.set_major_formatter(ticker.EngFormatter())
plt.show()

# %%
year = pd.DataFrame(Us_Accident.Start_Time.dt.year.value_counts()).reset_index().rename(columns={"index":"Year","Start_Time":"Accident_Cases"})

# %%
plt.figure(figsize=(8,4))
plt.title('\n Accident cases reported yearly in US (2016-2021)\n', size=20, color='black')
plt.xlabel('\n Year \n', fontsize=14, color='red')
plt.ylabel('\nAccident Cases\n', fontsize=14, color='red')
plt.xticks(fontsize=13)
plt.yticks(fontsize=12)
a = sns.barplot(x=year.Year, y = year.Accident_Cases,palette="rainbow")
a.yaxis.set_major_formatter(ticker.EngFormatter())
plt.show()

# %%
plt.figure(figsize=(15,6))
plt.title('\n Accident cases reported yearly in US (2016-2021)\n', size=15, color='black')
plt.xlabel('\n Year \n', fontsize=14, color='red')
plt.ylabel('\nAccident Cases\n', fontsize=14, color='red')
plt.xticks(fontsize=13)
plt.yticks(fontsize=12)
a = sns.lineplot(data = year, marker='o', x='Year', y='Accident_Cases', color = '#734dff', label="Yearly Road Accidents")
a.xaxis.set_ticks(year.Year)
a.yaxis.set_major_formatter(ticker.EngFormatter())

plt.show()

# %%
for (i,j) in zip(year.Year,range(0,6)):
  print("Percentage of accidents occuring in year {} is {:.2f}%".format(year.Year[j],(month.Accident_Cases[j]/year.Accident_Cases.sum())*100))
# Out:
# Percentage of accidents occuring in year 2021 is 16.66%
# Percentage of accidents occuring in year 2020 is 12.68%
# Percentage of accidents occuring in year 2019 is 10.51%
# Percentage of accidents occuring in year 2017 is 8.50%
# Percentage of accidents occuring in year 2018 is 7.96%
# Percentage of accidents occuring in year 2016 is 6.97%

# %% [markdown]
# ## Analyzing the Weather impact on accidents

# %%
# What are the weather conditions at the time of accicent occurence

weather_conditions = Us_Accident.groupby(['Weather_Condition']).count()['ID']
weather_conditions
# Out:
# Weather_Condition
# Blowing Dust                142
# Blowing Dust / Windy        148
# Blowing Sand                  1
# Blowing Snow                162
# Blowing Snow / Windy         86
#                            ...
# Volcanic Ash                  4
# Widespread Dust              50
# Widespread Dust / Windy      18
# Wintry Mix                 3843
# Wintry Mix / Windy           74
# Name: ID, Length: 127, dtype: int64

# %%
# Weather conditions at time of occurence sorted

weather_conditions.sort_values(ascending=False)
# Out:
# Weather_Condition
# Fair                         1107194
# Mostly Cloudy                 363959
# Cloudy                        348767
# Partly Cloudy                 249939
# Clear                         173823
#                               ...
# Low Drifting Snow                  1
# Light Fog                          1
# Mist / Windy                       1
# Sand / Dust Whirls Nearby          1
# Sleet / Windy                      1
# Name: ID, Length: 127, dtype: int64

# %%
weather_conditions.sort_values(ascending=False)[:20]
# Out:
# Weather_Condition
# Fair                       1107194
# Mostly Cloudy               363959
# Cloudy                      348767
# Partly Cloudy               249939
# Clear                       173823
# Light Rain                  128403
# Overcast                     84882
# Scattered Clouds             45132
# Light Snow                   43752
# Fog                          41226
# Haze                         36354
# Rain                         31044
# Fair / Windy                 15195
# Heavy Rain                   11824
# Smoke                         7200
# Light Drizzle                 7041
# Thunder in the Vicinity       6944
# Cloudy / Windy                6839
# T-Storm                       6546
# Mostly Cloudy / Windy         6297
# Name: ID, dtype: int64

# %%
plt.figure(figsize=(20,10))
Us_Accident.groupby('Weather_Condition') \
        .size() \
        .sort_values(ascending = False) \
        .iloc[:5] \
        .plot.pie(explode=[0,0,0.1,0,0],autopct='%1.1f%%',shadow=True)
plt.ioff()

# %%
# Let's visualize top 15 weather conditions at the time of accident occurence

fig, ax = plt.subplots(figsize=(15,6))
weather_conditions.sort_values(ascending=False)[:15].plot(kind='bar')
ax.set(title = 'Weather Conditions at Time of Accident Occurence',
       xlabel = 'Weather',
       ylabel = 'Accidents Count')
plt.show()

# %%
fig, ax=plt.subplots(figsize=(16,7))
Us_Accident['Weather_Condition'].value_counts().sort_values(ascending=False).head(5).plot.bar(width=0.5,edgecolor='k',align='center',linewidth=2)
plt.xlabel('Weather_Condition',fontsize=20)
plt.ylabel('Number of Accidents',fontsize=20)
ax.tick_params(labelsize=20)
plt.title('5 Top Weather Condition for accidents',fontsize=25)
plt.grid()
plt.ioff()

# %% [markdown]
# ## Street Analysis

# %%
Accidents_per_street=Us_Accident.Street.value_counts()
Accidents_per_street
# Out:
# I-95 N               39853
# I-5 N                39402
# I-95 S               36425
# I-5 S                30229
# I-10 E               26164
#                      ...
#  Villareal Dr            1
#  La Jacaranda            1
#  SW 273rd Ln             1
#  Silent Brook Dr         1
# 473-401 Cutoff Rd        1
# Name: Street, Length: 159651, dtype: int64

# %%
plt.title("Top Ten Dangerous Roads",color='blue',fontsize=15)
Accidents_per_street.head(10).plot(kind='barh',color='red',figsize=(15,7))

# %% [markdown]
# ## Analyzing the level of severity of the accidents

# %%
severity = Us_Accident.Severity.value_counts()/ len(Us_Accident.Severity)*100
severity
# Out:
# 2    89.022374
# 3     5.451190
# 4     4.610799
# 1     0.915637
# Name: Severity, dtype: float64

# %%
severity.plot.pie(subplots=True,  figsize=(20, 10))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f08e45eaf10>],
#       dtype=object)
